# %% [markdown]
# <a href="https://colab.research.google.com/github/raklives/practice-projects/blob/master/Trending_stories.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### IMPORT

# %%
 # libraries
import numpy as np 
import pandas as pd 
import json
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import cm
from datetime import datetime
import seaborn as sns

# %%
# csv files for United States, Canada, Great Britain
US = pd.read_csv('/content/USvideos.csv')
CA = pd.read_csv('/content/CAvideos.csv')
GB = pd.read_csv('/content/GBvideos.csv')

# %%
# check US data set
US.head(2)
# Out:
#       video_id  ...                                        description
# 0  2kyS6SvSYSE  ...  SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1  1ZAPwfrtAFY  ...  One year after the presidential election, John...
#
# [2 rows x 16 columns]

# %%
# add US id to all rows
US['country'] = 'US'

# %%
CA.head(1)
# Out:
#       video_id  ...                                        description
# 0  n1WpP7iowLc  ...  Eminem's new track Walk on Water ft. Beyoncé i...
#
# [1 rows x 16 columns]

# %%
# add column hold country name
CA['country'] = 'CA'
#check
CA.head()
# Out:
#       video_id  ... country
# 0  n1WpP7iowLc  ...      CA
# 1  0dBIkQ4Mz1M  ...      CA
# 2  5qpjK5DgCt4  ...      CA
# 3  d380meD0W0M  ...      CA
# 4  2Vv-BfVoq4g  ...      CA
#
# [5 rows x 17 columns]

# %%
# checkGB head
GB.head(2)
# Out:
#       video_id  ...                                        description
# 0  Jw1Y-zhQURU  ...  Click here to continue the story and make your...
# 1  3s1rvMFUweQ  ...  Musical guest Taylor Swift performs …Ready for...
#
# [2 rows x 16 columns]

# %%
GB['country'] = 'GB'
# check 
GB.head()
# Out:
#       video_id  ... country
# 0  Jw1Y-zhQURU  ...      GB
# 1  3s1rvMFUweQ  ...      GB
# 2  n1WpP7iowLc  ...      GB
# 3  PUTEiSjKwJU  ...      GB
# 4  rHwDegptbI4  ...      GB
#
# [5 rows x 17 columns]

# %%
# check the columns it has
print(US.columns)
print(US.shape)
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description', 'country'],
#       dtype='object')
# (40949, 17)

# %%
# attach US category IDs
with open("/content/US_category_id.json") as f:
    categories = json.load(f)["items"]
cat_dict = {}
for cat in categories:
    cat_dict[int(cat["id"])] = cat["snippet"]["title"]
US['category_name'] = US['category_id'].map(cat_dict)

# check
US.head()
# Out:
#       video_id trending_date  ... country   category_name
# 0  2kyS6SvSYSE      17.14.11  ...      US  People & Blogs
# 1  1ZAPwfrtAFY      17.14.11  ...      US   Entertainment
# 2  5qpjK5DgCt4      17.14.11  ...      US          Comedy
# 3  puqaWrEC7tY      17.14.11  ...      US   Entertainment
# 4  d380meD0W0M      17.14.11  ...      US   Entertainment
#
# [5 rows x 18 columns]

# %%
# check columns for CA
print(CA.columns)
print(CA.shape)
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description', 'country'],
#       dtype='object')
# (23326, 17)

# %%
# CA category ids
with open("/content/CA_category_id.json") as f:
    categories = json.load(f)["items"]
cat_dict = {}
for cat in categories:
    cat_dict[int(cat["id"])] = cat["snippet"]["title"]
CA['category_name'] = CA['category_id'].map(cat_dict)

# check
CA.head()
# Out:
#       video_id trending_date  ... country  category_name
# 0  n1WpP7iowLc      17.14.11  ...      CA          Music
# 1  0dBIkQ4Mz1M      17.14.11  ...      CA         Comedy
# 2  5qpjK5DgCt4      17.14.11  ...      CA         Comedy
# 3  d380meD0W0M      17.14.11  ...      CA  Entertainment
# 4  2Vv-BfVoq4g      17.14.11  ...      CA          Music
#
# [5 rows x 18 columns]

# %%
# check columns for GB
print(GB.columns)
print(GB.shape)
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description', 'country'],
#       dtype='object')
# (23371, 17)

# %%
# GB category ID
with open("/content/GB_category_id.json") as f:
    categories = json.load(f)["items"]
cat_dict = {}
for cat in categories:
    cat_dict[int(cat["id"])] = cat["snippet"]["title"]
GB['category_name'] = GB['category_id'].map(cat_dict)

# check
GB.head()
# Out:
#       video_id trending_date  ... country    category_name
# 0  Jw1Y-zhQURU      17.14.11  ...      GB    Howto & Style
# 1  3s1rvMFUweQ      17.14.11  ...      GB    Entertainment
# 2  n1WpP7iowLc      17.14.11  ...      GB            Music
# 3  PUTEiSjKwJU      17.14.11  ...      GB           Sports
# 4  rHwDegptbI4      17.14.11  ...      GB  News & Politics
#
# [5 rows x 18 columns]

# %% [markdown]
# ### The 3 countries share the same columns. This will make it easier to combine them.
# > now let's combine all three into a single data frames

# %%
# combine in single data fram
countries = pd.concat([CA, GB, US], axis=0)
print(countries.shape)
# Out:
# (87646, 18)

# %%
# check 
countries.head(40)
# Out:
#        video_id trending_date  ... country         category_name
# 0   n1WpP7iowLc      17.14.11  ...      CA                 Music
# 1   0dBIkQ4Mz1M      17.14.11  ...      CA                Comedy
# 2   5qpjK5DgCt4      17.14.11  ...      CA                Comedy
# 3   d380meD0W0M      17.14.11  ...      CA         Entertainment
# 4   2Vv-BfVoq4g      17.14.11  ...      CA                 Music
# 5   0yIWz1XEeyc      17.14.11  ...      CA       News & Politics
# 6   _uM5kFfkhB8      17.14.11  ...      CA                Comedy
# 7   2kyS6SvSYSE      17.14.11  ...      CA        People & Blogs
# 8   JzCsM1vtn78      17.14.11  ...      CA         Entertainment
# 9   43sm-QwLcx4      17.14.11  ...      CA        People & Blogs
# 10  H1KBHFXm2Bg      17.14.11  ...      CA                 Music
# 11  U3xLOo-CNwo      17.14.11  ...      CA         Howto & Style
# 12  FyZMnhUtLfE      17.14.11  ...      CA      Film & Animation
# ...

# %%
# make sure all countries are represented
countries['country'].unique()
# Out:
# array(['CA', 'GB', 'US'], dtype=object)

# %%
# check for missing values
print(countries.isnull().sum())
print('description is missing alot of data')
# Out:
# video_id                     0
# trending_date                0
# title                        0
# channel_title                0
# category_id                  0
# publish_time                 0
# tags                         0
# views                        0
# likes                        0
# dislikes                     0
# comment_count                0
# thumbnail_link               0
# comments_disabled            0
# ratings_disabled             0
# video_error_or_removed       0
# description               1664
# country                      0
# category_name              100
# dtype: int64
# description is missing alot of data

# %%
# info on the dataset
countries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87646 entries, 0 to 40948
# Data columns (total 18 columns):
# video_id                  87646 non-null object
# trending_date             87646 non-null object
# title                     87646 non-null object
# channel_title             87646 non-null object
# category_id               87646 non-null int64
# publish_time              87646 non-null object
# tags                      87646 non-null object
# views                     87646 non-null int64
# likes                     87646 non-null int64
# dislikes                  87646 non-null int64
# comment_count             87646 non-null int64
# thumbnail_link            87646 non-null object
# comments_disabled         87646 non-null bool
# ratings_disabled          87646 non-null bool
# video_error_or_removed    87646 non-null bool
# description               85982 non-null object
# country                   87646 non-null object
# ...

# %%
# replace null values in the description column
countries['description'] = countries['description'].fillna(value="")

# check
print(countries.info())
print('looks like we have no missing values')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87646 entries, 0 to 40948
# Data columns (total 18 columns):
# video_id                  87646 non-null object
# trending_date             87646 non-null object
# title                     87646 non-null object
# channel_title             87646 non-null object
# category_id               87646 non-null int64
# publish_time              87646 non-null object
# tags                      87646 non-null object
# views                     87646 non-null int64
# likes                     87646 non-null int64
# dislikes                  87646 non-null int64
# comment_count             87646 non-null int64
# thumbnail_link            87646 non-null object
# comments_disabled         87646 non-null bool
# ratings_disabled          87646 non-null bool
# video_error_or_removed    87646 non-null bool
# description               87646 non-null object
# country                   87646 non-null object
# ...

# %% [markdown]
# ### The Category Column is currently just a bunch of numbers. We need to convert to numbers to their actual meaning

# %%
# check
countries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87646 entries, 0 to 40948
# Data columns (total 18 columns):
# video_id                  87646 non-null object
# trending_date             87646 non-null object
# title                     87646 non-null object
# channel_title             87646 non-null object
# category_id               87646 non-null int64
# publish_time              87646 non-null object
# tags                      87646 non-null object
# views                     87646 non-null int64
# likes                     87646 non-null int64
# dislikes                  87646 non-null int64
# comment_count             87646 non-null int64
# thumbnail_link            87646 non-null object
# comments_disabled         87646 non-null bool
# ratings_disabled          87646 non-null bool
# video_error_or_removed    87646 non-null bool
# description               87646 non-null object
# country                   87646 non-null object
# ...

# %%
# replace null values in category ID
countries['category_name'] = countries['category_name'].fillna(value="")

# check
print(countries.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87646 entries, 0 to 40948
# Data columns (total 18 columns):
# video_id                  87646 non-null object
# trending_date             87646 non-null object
# title                     87646 non-null object
# channel_title             87646 non-null object
# category_id               87646 non-null int64
# publish_time              87646 non-null object
# tags                      87646 non-null object
# views                     87646 non-null int64
# likes                     87646 non-null int64
# dislikes                  87646 non-null int64
# comment_count             87646 non-null int64
# thumbnail_link            87646 non-null object
# comments_disabled         87646 non-null bool
# ratings_disabled          87646 non-null bool
# video_error_or_removed    87646 non-null bool
# description               87646 non-null object
# country                   87646 non-null object
# ...

# %%
# reset the dataframe index
countries.set_index(['video_id'], inplace=True)
countries.head(5)
# Out:
#             trending_date  ...  category_name
# video_id                   ...
# n1WpP7iowLc      17.14.11  ...          Music
# 0dBIkQ4Mz1M      17.14.11  ...         Comedy
# 5qpjK5DgCt4      17.14.11  ...         Comedy
# d380meD0W0M      17.14.11  ...  Entertainment
# 2Vv-BfVoq4g      17.14.11  ...          Music
#
# [5 rows x 17 columns]

# %%
# reformat the date time
countries['trending_date'] = pd.to_datetime(countries['trending_date'],
                                            errors='coerce', format='%y.%d.%m')
countries['publish_time'] = pd.to_datetime(countries['publish_time'], 
                                           errors='coerce',
                                           format='%Y-%m-%dT%H:%M:%S.%fZ')

# %%
# check
countries.head()
# Out:
#             trending_date  ...  category_name
# video_id                   ...
# n1WpP7iowLc    2017-11-14  ...          Music
# 0dBIkQ4Mz1M    2017-11-14  ...         Comedy
# 5qpjK5DgCt4    2017-11-14  ...         Comedy
# d380meD0W0M    2017-11-14  ...  Entertainment
# 2Vv-BfVoq4g    2017-11-14  ...          Music
#
# [5 rows x 17 columns]

# %%
# check data types, to make sure the strings and numerical data are
# appropriately represented
countries.dtypes
# Out:
# trending_date             datetime64[ns]
# title                             object
# channel_title                     object
# category_id                        int64
# publish_time              datetime64[ns]
# tags                              object
# views                              int64
# likes                              int64
# dislikes                           int64
# comment_count                      int64
# thumbnail_link                    object
# comments_disabled                   bool
# ratings_disabled                    bool
# video_error_or_removed              bool
# description                       object
# country                           object
# category_name                     object
# dtype: object

# %% [markdown]
# ### Basic Visualizations

# %%
# import seaborn
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.relplot(x='views', y = 'likes', data = countries, hue = 'comment_count')

# %%
sns.catplot(x='country', y='views', data=countries);

# %%
sns.countplot(y='category_name', data=US)

# %%
sns.countplot(y='category_name', data=GB)

# %%
sns.countplot(y='category_name', data=CA)

# %%
sns.barplot(x='country', y='likes', data=countries)

# %%
sns.pairplot(countries, hue='country')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
