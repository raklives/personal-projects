# %% [markdown]
# <a href="https://colab.research.google.com/github/raklives/practice-projects/blob/master/Trending_stories.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### IMPORT

# %%
 # libraries
import numpy as np 
import pandas as pd 
import json
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import cm
from datetime import datetime
import seaborn as sns

# %%
# csv files for United States, Canada, Great Britain
US = pd.read_csv('/content/USvideos.csv')
CA = pd.read_csv('/content/CAvideos.csv')
GB = pd.read_csv('/content/GBvideos.csv')

# %%
# check US data set
US.head(2)
# Out:
#       video_id  ...                                        description
# 0  2kyS6SvSYSE  ...  SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1  1ZAPwfrtAFY  ...  One year after the presidential election, John...
#
# [2 rows x 16 columns]

# %%
CA.head(1)
# Out:
#       video_id  ...                                        description
# 0  n1WpP7iowLc  ...  Eminem's new track Walk on Water ft. Beyoncé i...
#
# [1 rows x 16 columns]

# %%
# add column hold country name
CA['country'] = 'CA'
#check
CA.head()
# Out:
#       video_id  ... country
# 0  n1WpP7iowLc  ...      CA
# 1  0dBIkQ4Mz1M  ...      CA
# 2  5qpjK5DgCt4  ...      CA
# 3  d380meD0W0M  ...      CA
# 4  2Vv-BfVoq4g  ...      CA
#
# [5 rows x 17 columns]

# %%
# checkGB head
GB.head(2)
# Out:
#       video_id  ...                                        description
# 0  Jw1Y-zhQURU  ...  Click here to continue the story and make your...
# 1  3s1rvMFUweQ  ...  Musical guest Taylor Swift performs …Ready for...
#
# [2 rows x 16 columns]

# %%
GB['country'] = 'GB'
# check 
GB.head()
# Out:
#       video_id  ... country
# 0  Jw1Y-zhQURU  ...      GB
# 1  3s1rvMFUweQ  ...      GB
# 2  n1WpP7iowLc  ...      GB
# 3  PUTEiSjKwJU  ...      GB
# 4  rHwDegptbI4  ...      GB
#
# [5 rows x 17 columns]

# %%
# check the columns it has
print(US.columns)
print(US.shape)
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')
# (40949, 16)

# %%
# attach US category IDs
with open("/content/US_category_id.json") as f:
    categories = json.load(f)["items"]
cat_dict = {}
for cat in categories:
    cat_dict[int(cat["id"])] = cat["snippet"]["title"]
US['category_name'] = US['category_id'].map(cat_dict)

# check
US.head()
# Out:
#       video_id  ...   category_name
# 0  2kyS6SvSYSE  ...  People & Blogs
# 1  1ZAPwfrtAFY  ...   Entertainment
# 2  5qpjK5DgCt4  ...          Comedy
# 3  puqaWrEC7tY  ...   Entertainment
# 4  d380meD0W0M  ...   Entertainment
#
# [5 rows x 17 columns]

# %%
US['country'] = 'US'

# %%
# check columns for CA
print(CA.columns)
print(CA.shape)
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description', 'country'],
#       dtype='object')
# (23326, 17)

# %%
# CA category ids
with open("/content/CA_category_id.json") as f:
    categories = json.load(f)["items"]
cat_dict = {}
for cat in categories:
    cat_dict[int(cat["id"])] = cat["snippet"]["title"]
CA['category_name'] = CA['category_id'].map(cat_dict)

# check
CA.head()
# Out:
#       video_id trending_date  ... country  category_name
# 0  n1WpP7iowLc      17.14.11  ...      CA          Music
# 1  0dBIkQ4Mz1M      17.14.11  ...      CA         Comedy
# 2  5qpjK5DgCt4      17.14.11  ...      CA         Comedy
# 3  d380meD0W0M      17.14.11  ...      CA  Entertainment
# 4  2Vv-BfVoq4g      17.14.11  ...      CA          Music
#
# [5 rows x 18 columns]

# %%
# check columns for GB
print(GB.columns)
print(GB.shape)
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description', 'country'],
#       dtype='object')
# (23371, 17)

# %%
# GB category ID
with open("/content/GB_category_id.json") as f:
    categories = json.load(f)["items"]
cat_dict = {}
for cat in categories:
    cat_dict[int(cat["id"])] = cat["snippet"]["title"]
GB['category_name'] = GB['category_id'].map(cat_dict)

# check
GB.head()
# Out:
#       video_id trending_date  ... country    category_name
# 0  Jw1Y-zhQURU      17.14.11  ...      GB    Howto & Style
# 1  3s1rvMFUweQ      17.14.11  ...      GB    Entertainment
# 2  n1WpP7iowLc      17.14.11  ...      GB            Music
# 3  PUTEiSjKwJU      17.14.11  ...      GB           Sports
# 4  rHwDegptbI4      17.14.11  ...      GB  News & Politics
#
# [5 rows x 18 columns]

# %% [markdown]
# ### US has more observations compare to GB and CA.
# > So we'll create a new dataframe from a sample of the original data frame

# %%
# sample of US data
US = US.sample(n=23371, replace=False, axis=0)
US.shape
print('we now have a sample of ')
# Out:
# we now have a sample of

# %% [markdown]
# ### The 3 countries share the same columns. This will make it easier to combine them.
# > now let's combine all three into a single data frames

# %%
# combine in single data fram
countries = pd.concat([CA, GB, US], axis=0)
print(countries.shape)
# Out:
# (70068, 18)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
# check 
countries.head(40)
# Out:
#     category_id         category_name  ...     video_id     views
# 0            10                 Music  ...  n1WpP7iowLc  17158579
# 1            23                Comedy  ...  0dBIkQ4Mz1M   1014651
# 2            23                Comedy  ...  5qpjK5DgCt4   3191434
# 3            24         Entertainment  ...  d380meD0W0M   2095828
# 4            10                 Music  ...  2Vv-BfVoq4g  33523622
# 5            25       News & Politics  ...  0yIWz1XEeyc   1309699
# 6            23                Comedy  ...  _uM5kFfkhB8   2987945
# 7            22        People & Blogs  ...  2kyS6SvSYSE    748374
# 8            24         Entertainment  ...  JzCsM1vtn78   4477587
# 9            22        People & Blogs  ...  43sm-QwLcx4    505161
# 10           10                 Music  ...  H1KBHFXm2Bg   5068229
# 11           26         Howto & Style  ...  U3xLOo-CNwo   3153224
# 12            1      Film & Animation  ...  FyZMnhUtLfE    158815
# 13           10                 Music  ...  7MxiQ4v0EnE   5718766
# 14           24         Entertainment  ...  LUzsOyWp9lw    960747
# 15           22        People & Blogs  ...  AS9-ITLhQxo   1531218
# 16           23                Comedy  ...  gifPYwArCVQ    557883
# 17           24         Entertainment  ...  8NHA23f7LvU   1496225
# 18            1      Film & Animation  ...  fy-CuCzaPp8    308568
# 19            1      Film & Animation  ...  kzwfHumJyYc   1096327
# 20           28  Science & Technology  ...  nc99ccSXST0    817732
# 21           24         Entertainment  ...  puqaWrEC7tY    343168
# 22           22        People & Blogs  ...  6H3wVsceoS0   3905245
# 23           22        People & Blogs  ...  PRlmRnU9qts   4204818
# 24           24         Entertainment  ...  ZhhXLMbZ1rQ    549374
# 25           24         Entertainment  ...  wuf2KinLxZ8    348841
# 26           24         Entertainment  ...  aVTAU_4i9AY    370827
# 27           24         Entertainment  ...  7779JdxVAg0    653398
# 28           22        People & Blogs  ...  jVpp2BUtMoY     92280
# 29           10                 Music  ...  j67FgNEvyh8    178447
# 30           22        People & Blogs  ...  oQH_rtoHsdQ    585425
# 31           24         Entertainment  ...  m-nZmgHWoEw    116676
# 32           22        People & Blogs  ...  V4Uuxg6jmbo   3597410
# 33           20                Gaming  ...  WuTFI5qftCE    925222
# 34           22        People & Blogs  ...  _A5Z00E5gx8    123778
# 35           25       News & Politics  ...  wczm1faUZ1Q    200264
# 36           20                Gaming  ...  uEu5--lyNCE    191353
# 37           24         Entertainment  ...  cTBnDJ77kr0    721066
# 38           24         Entertainment  ...  FSdg3UVuBKE    182330
# 39           23                Comedy  ...  6xT1Xc7_X3k    524623
#
# [40 rows x 18 columns]

# %%
# make sure all countries are represented
countries['country'].unique()
# Out:
# array(['CA', 'GB', 'US'], dtype=object)

# %%
# check for missing values
print(countries.isnull().sum())
print('description is missing alot of data')
# Out:
# category_id                  0
# category_name              100
# channel_title                0
# comment_count                0
# comments_disabled            0
# country                      0
# description               1423
# dislikes                     0
# likes                        0
# publish_time                 0
# ratings_disabled             0
# tags                         0
# thumbnail_link               0
# title                        0
# trending_date                0
# video_error_or_removed       0
# video_id                     0
# views                        0
# dtype: int64
# description is missing alot of data

# %%
# info on the dataset
countries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 70068 entries, 0 to 5865
# Data columns (total 18 columns):
# category_id               70068 non-null int64
# category_name             69968 non-null object
# channel_title             70068 non-null object
# comment_count             70068 non-null int64
# comments_disabled         70068 non-null bool
# country                   70068 non-null object
# description               68645 non-null object
# dislikes                  70068 non-null int64
# likes                     70068 non-null int64
# publish_time              70068 non-null object
# ratings_disabled          70068 non-null bool
# tags                      70068 non-null object
# thumbnail_link            70068 non-null object
# title                     70068 non-null object
# trending_date             70068 non-null object
# video_error_or_removed    70068 non-null bool
# video_id                  70068 non-null object
# views                     70068 non-null int64
# dtypes: bool(3), int64(5), object(10)
# memory usage: 8.8+ MB

# %%
# replace null values in the description column
countries['description'] = countries['description'].fillna(value="")

# check
print(countries.info())
print('looks like we have no missing values')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 70068 entries, 0 to 25566
# Data columns (total 18 columns):
# category_id               70068 non-null int64
# category_name             69968 non-null object
# channel_title             70068 non-null object
# comment_count             70068 non-null int64
# comments_disabled         70068 non-null bool
# country                   70068 non-null object
# description               70068 non-null object
# dislikes                  70068 non-null int64
# likes                     70068 non-null int64
# publish_time              70068 non-null object
# ratings_disabled          70068 non-null bool
# tags                      70068 non-null object
# thumbnail_link            70068 non-null object
# title                     70068 non-null object
# trending_date             70068 non-null object
# video_error_or_removed    70068 non-null bool
# video_id                  70068 non-null object
# views                     70068 non-null int64
# dtypes: bool(3), int64(5), object(10)
# memory usage: 8.8+ MB
# None
# looks like we have no missing values

# %% [markdown]
# ### The Category Column is currently just a bunch of numbers. We need to convert to numbers to their actual meaning

# %%
# check
countries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 70068 entries, 0 to 5865
# Data columns (total 18 columns):
# category_id               70068 non-null int64
# category_name             69968 non-null object
# channel_title             70068 non-null object
# comment_count             70068 non-null int64
# comments_disabled         70068 non-null bool
# country                   70068 non-null object
# description               68645 non-null object
# dislikes                  70068 non-null int64
# likes                     70068 non-null int64
# publish_time              70068 non-null object
# ratings_disabled          70068 non-null bool
# tags                      70068 non-null object
# thumbnail_link            70068 non-null object
# title                     70068 non-null object
# trending_date             70068 non-null object
# video_error_or_removed    70068 non-null bool
# video_id                  70068 non-null object
# views                     70068 non-null int64
# dtypes: bool(3), int64(5), object(10)
# memory usage: 8.8+ MB

# %%
# replace null values in category ID
countries['category_name'] = countries['category_name'].fillna(value="")

# check
print(countries.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 70068 entries, 0 to 5865
# Data columns (total 18 columns):
# category_id               70068 non-null int64
# category_name             70068 non-null object
# channel_title             70068 non-null object
# comment_count             70068 non-null int64
# comments_disabled         70068 non-null bool
# country                   70068 non-null object
# description               68645 non-null object
# dislikes                  70068 non-null int64
# likes                     70068 non-null int64
# publish_time              70068 non-null object
# ratings_disabled          70068 non-null bool
# tags                      70068 non-null object
# thumbnail_link            70068 non-null object
# title                     70068 non-null object
# trending_date             70068 non-null object
# video_error_or_removed    70068 non-null bool
# video_id                  70068 non-null object
# views                     70068 non-null int64
# dtypes: bool(3), int64(5), object(10)
# memory usage: 8.8+ MB
# None

# %%
# reset the dataframe index
countries.set_index(['video_id'], inplace=True)
countries.head(5)
# Out:
#              category_id  category_name  ... video_error_or_removed     views
# video_id                                 ...
# n1WpP7iowLc           10          Music  ...                  False  17158579
# 0dBIkQ4Mz1M           23         Comedy  ...                  False   1014651
# 5qpjK5DgCt4           23         Comedy  ...                  False   3191434
# d380meD0W0M           24  Entertainment  ...                  False   2095828
# 2Vv-BfVoq4g           10          Music  ...                  False  33523622
#
# [5 rows x 17 columns]

# %%
# reformat the date time
countries['trending_date'] = pd.to_datetime(countries['trending_date'],
                                            errors='coerce', format='%y.%d.%m')
countries['publish_time'] = pd.to_datetime(countries['publish_time'], 
                                           errors='coerce',
                                           format='%Y-%m-%dT%H:%M:%S.%fZ')

# %%
# check
countries.head()
# Out:
#              category_id  category_name  ... video_error_or_removed     views
# video_id                                 ...
# n1WpP7iowLc           10          Music  ...                  False  17158579
# 0dBIkQ4Mz1M           23         Comedy  ...                  False   1014651
# 5qpjK5DgCt4           23         Comedy  ...                  False   3191434
# d380meD0W0M           24  Entertainment  ...                  False   2095828
# 2Vv-BfVoq4g           10          Music  ...                  False  33523622
#
# [5 rows x 17 columns]

# %% [markdown]
# ### Basic Visualizations

# %%
# set configuration
